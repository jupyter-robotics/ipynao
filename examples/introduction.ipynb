# %% [markdown]
# # Introduction

# %%
import ipynao
from ipywidgets import Output

import asyncio
# %gui asyncio

# %%
w = ipynao.NaoRobotWidget()
w

# %% [markdown]
# ### Connect to Robot

# %%
w.connect("192.168.1.115", port="80")
